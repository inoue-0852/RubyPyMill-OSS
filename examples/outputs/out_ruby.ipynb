# %%
name = "Ruby PyMill "
n = 2

for i in range(n+5):
    print(f"Hello, {name}! #{i+1}")
# Out:
# Hello, Ruby PyMill ! #1
# Hello, Ruby PyMill ! #2
# Hello, Ruby PyMill ! #3
# Hello, Ruby PyMill ! #4
# Hello, Ruby PyMill ! #5
# Hello, Ruby PyMill ! #6
# Hello, Ruby PyMill ! #7

# %%
# Parameters
name = "Ruby-PaperMill"
n = 2

# %%
Tags: ["run_only"]

for i in range(n):
    print(f"Hello, {name}! #{i+1}")
# Out:
# Hello, Ruby-PaperMill! #1
# Hello, Ruby-PaperMill! #2
