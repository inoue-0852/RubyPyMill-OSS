# %% [markdown]
# # Sample Notebook
# Parameters below.

# %%
name = "Ruby PyMill "
n = 5

# %%
# Parameters
name = "Ruby-PaperMill"
n = 3

# %%
Tags: ["run_only"]

for i in range(n):
    print(f"Hello, {name}! #{i+1}")
# Out:
# Hello, Ruby-PaperMill! #1
# Hello, Ruby-PaperMill! #2
# Hello, Ruby-PaperMill! #3
