# %% [markdown]
# # Sample Notebook
# Parameters below.

# %%
name = ""
n = 0

# %%
name = "Ruby PyMill "
n = 2

for i in range(n+5):
    print(f"Hello, {name}! #{i+1}")

# %%
Tags: ["run_only"]

for i in range(n):
    print(f"Hello, {name}! #{i+1}")
